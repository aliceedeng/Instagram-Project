# %%
import instaloader
from instaloader import *

# %%
L = instaloader.Instaloader()

# %%
L.login('jamaalhay','Jamaalhay_7')

# %%
me = Profile.from_username(L.context, 'jamaalhay')

# %%
#me = Profile.from_username(L.context, 'jamaalhay')
count = 0
folls = me.get_followees()
for name in folls:
    count += name.mediacount
    if count < 27976:
        print(count)
        continue
    for post in name.get_posts():
        save_structure_to_file(post, 'Posts/' + str(post.mediaid) + '.json')
# Out:
# 139
# 159
# 211
# 230
# 237
# 246
# 255
# 307
# 896
# 897
# 904
# 938
# 968
# 990
# 1181
# 1216
# 1216
# 1233
# 1307
# 1313
# 1326
# 1349
# 1367
# 1370
# 1415
# 1420
# 1730
# 1769
# 1771
# 1838
# 1855
# 1887
# 9838
# 9855
# 9936
# 9975
# 10222
# 10267
# 10270
# 10390
# 10403
# 10440
# 10440
# 10478
# 10501
# 10514
# 10603
# 10803
# 10806
# 10929
# 10932
# 10943
# 10950
# 10972
# 11046
# 11167
# 11236
# 11239
# 11250
# 11607
# 11633
# 11637
# 22247
# 22250
# 22257
# 22994
# 23132
# 23245
# 23370
# 23604
# 23652
# 23994
# 24374
# 24392
# 24395
# 24479
# 24636
# 24654
# 24698
# 24774
# 24813
# 24996
# 25050
# 25103
# 25192
# 25195
# 26191
# 26201
# 26251
# 26257
# 26295
# 26320
# 26432
# 26477
# 26492
# 26547
# 26605
# 26611
# 26619
# 26951
# 26951
# 26991
# 27135
# 27188
# 27219
# 27297
# 27405
# 27414
# 27525
# 27526
#
# Too many queries in the last time. Need to wait 617 seconds, until 15:14.
#
# Too many queries in the last time. Need to wait 603 seconds, until 15:25.
#
# Too many queries in the last time. Need to wait 607 seconds, until 15:36.
#
# Too many queries in the last time. Need to wait 12 seconds, until 15:37.
#
# Too many queries in the last time. Need to wait 594 seconds, until 15:47.
#
# Too many queries in the last time. Need to wait 16 seconds, until 15:48.
#
# Too many queries in the last time. Need to wait 596 seconds, until 15:58.
#
# Too many queries in the last time. Need to wait 14 seconds, until 15:59.
#
# Too many queries in the last time. Need to wait 594 seconds, until 16:09.
#
# Too many queries in the last time. Need to wait 598 seconds, until 16:21.
#
# Too many queries in the last time. Need to wait 597 seconds, until 16:32.
#
# Too many queries in the last time. Need to wait 601 seconds, until 16:43.
#
# Too many queries in the last time. Need to wait 597 seconds, until 16:54.
#
# Too many queries in the last time. Need to wait 11 seconds, until 16:54.
#
# Too many queries in the last time. Need to wait 599 seconds, until 17:05.
#
# Too many queries in the last time. Need to wait 17 seconds, until 17:05.
#
# Too many queries in the last time. Need to wait 596 seconds, until 17:16.
#
# Too many queries in the last time. Need to wait 12 seconds, until 17:17.
#
# Too many queries in the last time. Need to wait 598 seconds, until 17:27.
#
# Too many queries in the last time. Need to wait 16 seconds, until 17:28.
#
# Too many queries in the last time. Need to wait 596 seconds, until 17:38.
#
# Too many queries in the last time. Need to wait 11 seconds, until 17:39.
#
# Too many queries in the last time. Need to wait 603 seconds, until 17:49.
#
# Too many queries in the last time. Need to wait 14 seconds, until 17:50.
#
# Too many queries in the last time. Need to wait 605 seconds, until 18:00.
#
# Too many queries in the last time. Need to wait 14 seconds, until 18:01.
#
# Too many queries in the last time. Need to wait 601 seconds, until 18:12.
#
# Too many queries in the last time. Need to wait 17 seconds, until 18:12.
#
# Too many queries in the last time. Need to wait 601 seconds, until 18:23.
#
# Too many queries in the last time. Need to wait 19 seconds, until 18:23.
#
# Too many queries in the last time. Need to wait 603 seconds, until 18:34.
#
# Too many queries in the last time. Need to wait 21 seconds, until 18:34.
#
# Too many queries in the last time. Need to wait 600 seconds, until 18:45.
#
# Too many queries in the last time. Need to wait 12 seconds, until 18:45.
#
# Too many queries in the last time. Need to wait 603 seconds, until 18:56.
#
# Too many queries in the last time. Need to wait 16 seconds, until 18:56.
#
# Too many queries in the last time. Need to wait 602 seconds, until 19:07.
#
# Too many queries in the last time. Need to wait 19 seconds, until 19:08.
#
# Too many queries in the last time. Need to wait 601 seconds, until 19:18.
#
# Too many queries in the last time. Need to wait 16 seconds, until 19:19.
#
# Too many queries in the last time. Need to wait 599 seconds, until 19:29.
#
# Too many queries in the last time. Need to wait 21 seconds, until 19:30.
#
# Too many queries in the last time. Need to wait 599 seconds, until 19:40.
#
# Too many queries in the last time. Need to wait 592 seconds, until 19:51.
#
# Too many queries in the last time. Need to wait 15 seconds, until 19:52.
#
# Too many queries in the last time. Need to wait 596 seconds, until 20:03.
#
# Too many queries in the last time. Need to wait 16 seconds, until 20:03.
#
# Too many queries in the last time. Need to wait 588 seconds, until 20:14.
#
# Too many queries in the last time. Need to wait 11 seconds, until 20:14.
#
# Too many queries in the last time. Need to wait 595 seconds, until 20:25.
#
# Too many queries in the last time. Need to wait 13 seconds, until 20:25.
#
# Too many queries in the last time. Need to wait 598 seconds, until 20:36.
#
# Too many queries in the last time. Need to wait 582 seconds, until 20:47.
#
# Too many queries in the last time. Need to wait 577 seconds, until 20:58.
#
# Too many queries in the last time. Need to wait 590 seconds, until 21:09.
#
# Too many queries in the last time. Need to wait 12 seconds, until 21:10.
#
# Too many queries in the last time. Need to wait 582 seconds, until 21:20.
#
# Too many queries in the last time. Need to wait 583 seconds, until 21:31.
#
# Too many queries in the last time. Need to wait 13 seconds, until 21:32.
#
# Too many queries in the last time. Need to wait 11 seconds, until 21:32.
#
# Too many queries in the last time. Need to wait 13 seconds, until 21:33.
#
# Too many queries in the last time. Need to wait 582 seconds, until 21:42.
#
# Too many queries in the last time. Need to wait 12 seconds, until 21:43.
#
# Too many queries in the last time. Need to wait 16 seconds, until 21:44.
#
# Too many queries in the last time. Need to wait 584 seconds, until 21:54.
#
# Too many queries in the last time. Need to wait 11 seconds, until 21:54.
#
# Too many queries in the last time. Need to wait 15 seconds, until 21:55.
#
# Too many queries in the last time. Need to wait 583 seconds, until 22:05.
#
# Too many queries in the last time. Need to wait 12 seconds, until 22:05.
#
# Too many queries in the last time. Need to wait 11 seconds, until 22:05.
#
# Too many queries in the last time. Need to wait 12 seconds, until 22:05.
#
# Too many queries in the last time. Need to wait 583 seconds, until 22:16.
#
# Too many queries in the last time. Need to wait 12 seconds, until 22:16.
#
# Too many queries in the last time. Need to wait 586 seconds, until 22:27.
#
# Too many queries in the last time. Need to wait 15 seconds, until 22:27.
#
# Too many queries in the last time. Need to wait 582 seconds, until 22:38.
#
# Too many queries in the last time. Need to wait 15 seconds, until 22:39.
#
# Too many queries in the last time. Need to wait 588 seconds, until 22:49.
#
# Too many queries in the last time. Need to wait 11 seconds, until 22:49.
#
# Too many queries in the last time. Need to wait 11 seconds, until 22:50.
#
# Too many queries in the last time. Need to wait 12 seconds, until 22:50.
#
# Too many queries in the last time. Need to wait 585 seconds, until 23:00.
#
# Too many queries in the last time. Need to wait 13 seconds, until 23:01.
#
# Too many queries in the last time. Need to wait 584 seconds, until 23:11.
#
# Too many queries in the last time. Need to wait 11 seconds, until 23:12.
#
# Too many queries in the last time. Need to wait 13 seconds, until 23:12.
#
# Too many queries in the last time. Need to wait 586 seconds, until 23:22.
#
# Too many queries in the last time. Need to wait 11 seconds, until 23:23.
#
# Too many queries in the last time. Need to wait 577 seconds, until 23:33.
#
# Too many queries in the last time. Need to wait 11 seconds, until 23:34.
#
# Too many queries in the last time. Need to wait 557 seconds, until 23:44.
#
# Too many queries in the last time. Need to wait 11 seconds, until 23:45.
#
# Too many queries in the last time. Need to wait 561 seconds, until 23:56.
#
# Too many queries in the last time. Need to wait 12 seconds, until 23:56.
#
# Too many queries in the last time. Need to wait 15 seconds, until 23:57.
#
# Too many queries in the last time. Need to wait 561 seconds, until 00:07.
#
# Too many queries in the last time. Need to wait 14 seconds, until 00:08.
#
# Too many queries in the last time. Need to wait 12 seconds, until 00:08.
#
# Too many queries in the last time. Need to wait 568 seconds, until 00:18.
#
# Too many queries in the last time. Need to wait 14 seconds, until 00:19.
#
# Too many queries in the last time. Need to wait 568 seconds, until 00:29.
#
# Too many queries in the last time. Need to wait 17 seconds, until 00:30.
#
# Too many queries in the last time. Need to wait 562 seconds, until 00:40.
#
# Too many queries in the last time. Need to wait 11 seconds, until 00:41.
#
# Too many queries in the last time. Need to wait 14 seconds, until 00:42.
#
# Too many queries in the last time. Need to wait 561 seconds, until 00:51.
#
# Too many queries in the last time. Need to wait 14 seconds, until 00:52.
#
# Too many queries in the last time. Need to wait 15 seconds, until 00:53.
#
# Too many queries in the last time. Need to wait 563 seconds, until 01:02.
#
# Too many queries in the last time. Need to wait 18 seconds, until 01:03.
#
# Too many queries in the last time. Need to wait 14 seconds, until 01:04.
#
# Too many queries in the last time. Need to wait 559 seconds, until 01:13.
#
# Too many queries in the last time. Need to wait 14 seconds, until 01:14.
#
# Too many queries in the last time. Need to wait 14 seconds, until 01:15.
#
# Too many queries in the last time. Need to wait 564 seconds, until 01:24.
#
# Too many queries in the last time. Need to wait 17 seconds, until 01:25.
#
# Too many queries in the last time. Need to wait 13 seconds, until 01:26.
#
# Too many queries in the last time. Need to wait 567 seconds, until 01:35.
#
# Too many queries in the last time. Need to wait 16 seconds, until 01:37.
#
# Too many queries in the last time. Need to wait 563 seconds, until 01:47.
#
# Too many queries in the last time. Need to wait 11 seconds, until 01:47.
#
# Too many queries in the last time. Need to wait 22 seconds, until 01:48.
#
# Too many queries in the last time. Need to wait 564 seconds, until 01:58.
#
# Too many queries in the last time. Need to wait 21 seconds, until 01:59.
#
# Too many queries in the last time. Need to wait 564 seconds, until 02:09.
#
# Too many queries in the last time. Need to wait 12 seconds, until 02:09.
#
# Too many queries in the last time. Need to wait 24 seconds, until 02:10.
#
# Too many queries in the last time. Need to wait 11 seconds, until 02:10.
#
# Too many queries in the last time. Need to wait 563 seconds, until 02:20.
#
# Too many queries in the last time. Need to wait 12 seconds, until 02:20.
#
# Too many queries in the last time. Need to wait 28 seconds, until 02:21.
#
# Too many queries in the last time. Need to wait 564 seconds, until 02:31.
#
# Too many queries in the last time. Need to wait 30 seconds, until 02:32.
#
# Too many queries in the last time. Need to wait 567 seconds, until 02:42.
#
# Too many queries in the last time. Need to wait 23 seconds, until 02:43.
#
# Too many queries in the last time. Need to wait 566 seconds, until 02:53.
#
# Too many queries in the last time. Need to wait 19 seconds, until 02:54.
#
# Too many queries in the last time. Need to wait 11 seconds, until 02:55.
#
# Too many queries in the last time. Need to wait 563 seconds, until 03:04.
#
# Too many queries in the last time. Need to wait 11 seconds, until 03:05.
#
# Too many queries in the last time. Need to wait 19 seconds, until 03:05.
#
# Too many queries in the last time. Need to wait 565 seconds, until 03:15.
#
# Too many queries in the last time. Need to wait 11 seconds, until 03:16.
#
# Too many queries in the last time. Need to wait 20 seconds, until 03:16.
#
# Too many queries in the last time. Need to wait 12 seconds, until 03:17.
#
# Too many queries in the last time. Need to wait 565 seconds, until 03:26.
#
# Too many queries in the last time. Need to wait 16 seconds, until 03:27.
#
# Too many queries in the last time. Need to wait 23 seconds, until 03:28.
#
# Too many queries in the last time. Need to wait 11 seconds, until 03:28.
#
# Too many queries in the last time. Need to wait 569 seconds, until 03:38.
#
# Too many queries in the last time. Need to wait 15 seconds, until 03:38.
#
# Too many queries in the last time. Need to wait 21 seconds, until 03:39.
#
# Too many queries in the last time. Need to wait 11 seconds, until 03:39.
#
# Too many queries in the last time. Need to wait 11 seconds, until 03:39.
#
# Too many queries in the last time. Need to wait 566 seconds, until 03:49.
#
# Too many queries in the last time. Need to wait 16 seconds, until 03:49.
#
# Too many queries in the last time. Need to wait 14 seconds, until 03:50.
#
# Too many queries in the last time. Need to wait 11 seconds, until 03:50.
#
# Too many queries in the last time. Need to wait 565 seconds, until 04:00.
#
# Too many queries in the last time. Need to wait 11 seconds, until 04:00.
#
# Too many queries in the last time. Need to wait 11 seconds, until 04:01.
#
# Too many queries in the last time. Need to wait 568 seconds, until 04:11.
#
# Too many queries in the last time. Need to wait 13 seconds, until 04:12.
#
# Too many queries in the last time. Need to wait 13 seconds, until 04:12.
#
# Too many queries in the last time. Need to wait 566 seconds, until 04:22.
#
# Too many queries in the last time. Need to wait 16 seconds, until 04:23.
#
# Too many queries in the last time. Need to wait 563 seconds, until 04:33.
#
# Too many queries in the last time. Need to wait 17 seconds, until 04:34.
#
# Too many queries in the last time. Need to wait 568 seconds, until 04:44.
#
# Too many queries in the last time. Need to wait 15 seconds, until 04:45.
#
# Too many queries in the last time. Need to wait 21 seconds, until 04:45.
#
# Too many queries in the last time. Need to wait 11 seconds, until 04:46.
#
# Too many queries in the last time. Need to wait 12 seconds, until 04:46.
#
# Too many queries in the last time. Need to wait 566 seconds, until 04:55.
#
# Too many queries in the last time. Need to wait 14 seconds, until 04:56.
#
# Too many queries in the last time. Need to wait 20 seconds, until 04:56.
#
# Too many queries in the last time. Need to wait 12 seconds, until 04:57.
#
# Too many queries in the last time. Need to wait 11 seconds, until 04:57.
#
# Too many queries in the last time. Need to wait 567 seconds, until 05:06.
#
# Too many queries in the last time. Need to wait 17 seconds, until 05:07.
#
# Too many queries in the last time. Need to wait 20 seconds, until 05:07.
#
# Too many queries in the last time. Need to wait 12 seconds, until 05:08.
#
# Too many queries in the last time. Need to wait 11 seconds, until 05:08.
#
# Too many queries in the last time. Need to wait 567 seconds, until 05:18.
#
# Too many queries in the last time. Need to wait 20 seconds, until 05:18.
#
# Too many queries in the last time. Need to wait 15 seconds, until 05:19.
#
# Too many queries in the last time. Need to wait 568 seconds, until 05:29.
#
# Too many queries in the last time. Need to wait 20 seconds, until 05:29.
#
# Too many queries in the last time. Need to wait 22 seconds, until 05:30.
#
# Too many queries in the last time. Need to wait 572 seconds, until 05:40.
#
# Too many queries in the last time. Need to wait 19 seconds, until 05:40.
#
# Too many queries in the last time. Need to wait 21 seconds, until 05:41.
#
# Too many queries in the last time. Need to wait 578 seconds, until 05:51.
#
# Too many queries in the last time. Need to wait 14 seconds, until 05:51.
#
# Too many queries in the last time. Need to wait 15 seconds, until 05:52.
#
# Too many queries in the last time. Need to wait 11 seconds, until 05:52.
#
# Too many queries in the last time. Need to wait 578 seconds, until 06:02.
#
# Too many queries in the last time. Need to wait 23 seconds, until 06:03.
#
# Too many queries in the last time. Need to wait 21 seconds, until 06:03.
#
# Too many queries in the last time. Need to wait 12 seconds, until 06:03.
#
# Too many queries in the last time. Need to wait 575 seconds, until 06:13.
#
# Too many queries in the last time. Need to wait 19 seconds, until 06:14.
#
# Too many queries in the last time. Need to wait 23 seconds, until 06:14.
#
# Too many queries in the last time. Need to wait 572 seconds, until 06:24.
#
# Too many queries in the last time. Need to wait 16 seconds, until 06:25.
#
# Too many queries in the last time. Need to wait 12 seconds, until 06:25.
#
# Too many queries in the last time. Need to wait 13 seconds, until 06:25.
#
# Too many queries in the last time. Need to wait 576 seconds, until 06:35.
#
# Too many queries in the last time. Need to wait 13 seconds, until 06:36.
#
# Too many queries in the last time. Need to wait 19 seconds, until 06:36.
#
# Too many queries in the last time. Need to wait 574 seconds, until 06:46.
#
# Too many queries in the last time. Need to wait 20 seconds, until 06:47.
#
# Too many queries in the last time. Need to wait 14 seconds, until 06:47.
#
# Too many queries in the last time. Need to wait 583 seconds, until 06:57.
#
# Too many queries in the last time. Need to wait 21 seconds, until 06:58.
#
# Too many queries in the last time. Need to wait 17 seconds, until 06:58.
#
# Too many queries in the last time. Need to wait 585 seconds, until 07:08.
#
# Too many queries in the last time. Need to wait 11 seconds, until 07:09.
#
# Too many queries in the last time. Need to wait 19 seconds, until 07:10.
#
# Too many queries in the last time. Need to wait 584 seconds, until 07:20.
#
# Too many queries in the last time. Need to wait 16 seconds, until 07:20.
#
# Too many queries in the last time. Need to wait 20 seconds, until 07:21.
#
# Too many queries in the last time. Need to wait 584 seconds, until 07:31.
#
# Too many queries in the last time. Need to wait 17 seconds, until 07:31.
#
# Too many queries in the last time. Need to wait 23 seconds, until 07:32.
#
# Too many queries in the last time. Need to wait 582 seconds, until 07:42.
#
# Too many queries in the last time. Need to wait 17 seconds, until 07:42.
#
# Too many queries in the last time. Need to wait 17 seconds, until 07:43.
#
# Too many queries in the last time. Need to wait 584 seconds, until 07:53.
#
# Too many queries in the last time. Need to wait 15 seconds, until 07:54.
#
# Too many queries in the last time. Need to wait 585 seconds, until 08:04.
#
# Too many queries in the last time. Need to wait 11 seconds, until 08:05.
#
# Too many queries in the last time. Need to wait 586 seconds, until 08:15.
#
# Too many queries in the last time. Need to wait 18 seconds, until 08:16.
#
# Too many queries in the last time. Need to wait 566 seconds, until 08:26.
#
# Too many queries in the last time. Need to wait 11 seconds, until 08:27.
#
# Too many queries in the last time. Need to wait 566 seconds, until 08:37.
#
# Too many queries in the last time. Need to wait 15 seconds, until 08:38.
#
# Too many queries in the last time. Need to wait 570 seconds, until 08:48.
#
# Too many queries in the last time. Need to wait 17 seconds, until 08:49.
#
# Too many queries in the last time. Need to wait 570 seconds, until 08:59.
#
# Too many queries in the last time. Need to wait 12 seconds, until 09:00.
#
# Too many queries in the last time. Need to wait 18 seconds, until 09:01.
# JSON Query to graphql/query: ('Connection broken: OSError("(54, \'ECONNRESET\')",)', OSError("(54, 'ECONNRESET')",)) [retrying; skip with ^C]
# Too many queries in the last time. Need to wait 573 seconds, until 09:11.
#
# Too many queries in the last time. Need to wait 18 seconds, until 09:12.
#
# Too many queries in the last time. Need to wait 567 seconds, until 09:22.
#
# Too many queries in the last time. Need to wait 16 seconds, until 09:23.
#
# Too many queries in the last time. Need to wait 558 seconds, until 09:33.
#
# Too many queries in the last time. Need to wait 23 seconds, until 09:34.
#
# Too many queries in the last time. Need to wait 576 seconds, until 09:44.
#
# Too many queries in the last time. Need to wait 23 seconds, until 09:45.
#
# Too many queries in the last time. Need to wait 582 seconds, until 09:55.
#
# Too many queries in the last time. Need to wait 13 seconds, until 09:55.
#
# Too many queries in the last time. Need to wait 18 seconds, until 09:56.
#
# Too many queries in the last time. Need to wait 578 seconds, until 10:06.
#
# Too many queries in the last time. Need to wait 15 seconds, until 10:07.
#
# Too many queries in the last time. Need to wait 19 seconds, until 10:07.
#
# Too many queries in the last time. Need to wait 579 seconds, until 10:17.
#
# Too many queries in the last time. Need to wait 18 seconds, until 10:18.
#
# Too many queries in the last time. Need to wait 578 seconds, until 10:28.
#
# Too many queries in the last time. Need to wait 11 seconds, until 10:29.
#
# Too many queries in the last time. Need to wait 15 seconds, until 10:29.
#
# Too many queries in the last time. Need to wait 574 seconds, until 10:40.
#
# Too many queries in the last time. Need to wait 15 seconds, until 11:18.
#
# Too many queries in the last time. Need to wait 18 seconds, until 11:19.
#
# Too many queries in the last time. Need to wait 575 seconds, until 11:29.
#
# Too many queries in the last time. Need to wait 14 seconds, until 11:30.
#
# Too many queries in the last time. Need to wait 18 seconds, until 11:30.
#
# Too many queries in the last time. Need to wait 573 seconds, until 11:40.
#
# Too many queries in the last time. Need to wait 17 seconds, until 13:13.
#
# Too many queries in the last time. Need to wait 574 seconds, until 13:23.
#
# Too many queries in the last time. Need to wait 15 seconds, until 13:23.
#
# Too many queries in the last time. Need to wait 17 seconds, until 13:24.
#
# Too many queries in the last time. Need to wait 576 seconds, until 13:34.
#
# Too many queries in the last time. Need to wait 14 seconds, until 13:34.
#
# Too many queries in the last time. Need to wait 13 seconds, until 13:35.
#
# Too many queries in the last time. Need to wait 575 seconds, until 13:45.
#
# Too many queries in the last time. Need to wait 11 seconds, until 14:03.
#
# Too many queries in the last time. Need to wait 17 seconds, until 14:04.
#
# Too many queries in the last time. Need to wait 576 seconds, until 14:14.
#
# Too many queries in the last time. Need to wait 15 seconds, until 14:14.
#
# Too many queries in the last time. Need to wait 17 seconds, until 14:15.
#
# Too many queries in the last time. Need to wait 574 seconds, until 14:25.
#
# Too many queries in the last time. Need to wait 14 seconds, until 14:26.
#
# Too many queries in the last time. Need to wait 18 seconds, until 14:26.
#
# Too many queries in the last time. Need to wait 579 seconds, until 14:36.
#
# Too many queries in the last time. Need to wait 12 seconds, until 14:37.
#
# Too many queries in the last time. Need to wait 21 seconds, until 14:37.
#
# Too many queries in the last time. Need to wait 11 seconds, until 14:37.
#
# Too many queries in the last time. Need to wait 572 seconds, until 14:47.
#
# Too many queries in the last time. Need to wait 11 seconds, until 14:48.
#
# Too many queries in the last time. Need to wait 572 seconds, until 14:58.
#
# Too many queries in the last time. Need to wait 577 seconds, until 15:10.
#
# Too many queries in the last time. Need to wait 12 seconds, until 15:10.
#
# Too many queries in the last time. Need to wait 575 seconds, until 15:21.
#
# Too many queries in the last time. Need to wait 15 seconds, until 15:21.
#
# Too many queries in the last time. Need to wait 572 seconds, until 15:32.
#
# Too many queries in the last time. Need to wait 16 seconds, until 15:32.
#
# Too many queries in the last time. Need to wait 575 seconds, until 15:43.
#
# Too many queries in the last time. Need to wait 11 seconds, until 15:44.
#
# Too many queries in the last time. Need to wait 576 seconds, until 15:54.
#
# Too many queries in the last time. Need to wait 576 seconds, until 16:05.
#
# Too many queries in the last time. Need to wait 574 seconds, until 16:16.
#
# Too many queries in the last time. Need to wait 11 seconds, until 16:17.
#
# Too many queries in the last time. Need to wait 565 seconds, until 16:27.
#
# Too many queries in the last time. Need to wait 566 seconds, until 16:38.
#
# Too many queries in the last time. Need to wait 13 seconds, until 16:39.
#
# Too many queries in the last time. Need to wait 19 seconds, until 16:40.
#
# Too many queries in the last time. Need to wait 565 seconds, until 16:49.
#
# Too many queries in the last time. Need to wait 566 seconds, until 17:01.
#
# Too many queries in the last time. Need to wait 15 seconds, until 17:02.
#
# Too many queries in the last time. Need to wait 564 seconds, until 17:12.
#
# Too many queries in the last time. Need to wait 12 seconds, until 17:12.
#
# Too many queries in the last time. Need to wait 13 seconds, until 17:13.
#
# Too many queries in the last time. Need to wait 561 seconds, until 17:23.
#
# Too many queries in the last time. Need to wait 13 seconds, until 17:23.
#
# Too many queries in the last time. Need to wait 18 seconds, until 17:24.
#
# Too many queries in the last time. Need to wait 566 seconds, until 17:34.
#
# Too many queries in the last time. Need to wait 559 seconds, until 17:45.
#
# Too many queries in the last time. Need to wait 11 seconds, until 17:46.
#
# Too many queries in the last time. Need to wait 560 seconds, until 17:56.
#
# Too many queries in the last time. Need to wait 563 seconds, until 18:07.
#
# Too many queries in the last time. Need to wait 11 seconds, until 18:08.
#
# Too many queries in the last time. Need to wait 563 seconds, until 18:18.
#
# Too many queries in the last time. Need to wait 12 seconds, until 18:20.
#
# Too many queries in the last time. Need to wait 559 seconds, until 18:29.
#
# Too many queries in the last time. Need to wait 13 seconds, until 18:30.
#
# Too many queries in the last time. Need to wait 565 seconds, until 18:40.
#
# Too many queries in the last time. Need to wait 568 seconds, until 18:52.
#
# Too many queries in the last time. Need to wait 13 seconds, until 18:52.
#
# Too many queries in the last time. Need to wait 26 seconds, until 18:52.
#
# Too many queries in the last time. Need to wait 567 seconds, until 19:03.
#
# Too many queries in the last time. Need to wait 13 seconds, until 19:03.
#
# Too many queries in the last time. Need to wait 26 seconds, until 19:03.
#
# Too many queries in the last time. Need to wait 553 seconds, until 19:14.
#
# Too many queries in the last time. Need to wait 25 seconds, until 19:15.
#
# Too many queries in the last time. Need to wait 11 seconds, until 19:15.
#
# Too many queries in the last time. Need to wait 554 seconds, until 19:25.
#
# Too many queries in the last time. Need to wait 28 seconds, until 19:26.
#
# Too many queries in the last time. Need to wait 559 seconds, until 19:36.
#
# Too many queries in the last time. Need to wait 30 seconds, until 19:37.
#
# Too many queries in the last time. Need to wait 558 seconds, until 19:47.
#
# Too many queries in the last time. Need to wait 12 seconds, until 19:47.
#
# Too many queries in the last time. Need to wait 26 seconds, until 19:48.
#
# Too many queries in the last time. Need to wait 11 seconds, until 19:48.
#
# Too many queries in the last time. Need to wait 554 seconds, until 19:58.
#
# Too many queries in the last time. Need to wait 30 seconds, until 19:59.
#
# Too many queries in the last time. Need to wait 15 seconds, until 19:59.
#
# Too many queries in the last time. Need to wait 558 seconds, until 20:09.
#
# Too many queries in the last time. Need to wait 13 seconds, until 20:10.
#
# Too many queries in the last time. Need to wait 30 seconds, until 20:10.
#
# Too many queries in the last time. Need to wait 20 seconds, until 20:10.
#
# Too many queries in the last time. Need to wait 556 seconds, until 20:20.
#
# Too many queries in the last time. Need to wait 25 seconds, until 20:21.
#
# Too many queries in the last time. Need to wait 12 seconds, until 20:22.
#
# Too many queries in the last time. Need to wait 548 seconds, until 20:31.
#
# Too many queries in the last time. Need to wait 31 seconds, until 20:32.
#
# Too many queries in the last time. Need to wait 14 seconds, until 20:33.
#
# Too many queries in the last time. Need to wait 548 seconds, until 20:43.
#
# Too many queries in the last time. Need to wait 36 seconds, until 20:43.
#
# Too many queries in the last time. Need to wait 17 seconds, until 20:44.
#
# Too many queries in the last time. Need to wait 13 seconds, until 20:44.
#
# Too many queries in the last time. Need to wait 546 seconds, until 20:54.
#
# Too many queries in the last time. Need to wait 31 seconds, until 20:54.
#
# Too many queries in the last time. Need to wait 12 seconds, until 20:55.
#
# Too many queries in the last time. Need to wait 14 seconds, until 20:55.

# %%
profile = Profile.from_username(L.context, 'sabrinafacey')
num = profile.mediacount
num
# Out:
# 116

# %%
profile.followers
# Out:
# 1315

# %%
count = 0
for post in profile.get_posts():
    count += 1
    save_structure_to_file(post, 'Posts/' + str(post.mediaid) + '.json')
    if count < 5:

# %%
import os

# define the name of the directory to be created
path = "Posts"

try:  
    os.mkdir(path)
except OSError:  
    print ("Creation of the directory %s failed" % path)
else:  
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory Posts
